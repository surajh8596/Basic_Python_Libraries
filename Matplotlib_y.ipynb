# %%
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
a=np.array([1,2,3,4,5])
b=np.array([4,5,6,7,8])
plt.plot(a, c='green', linewidth= 3, linestyle='--', label='line 1')
plt.plot(b, c='black', linewidth=5, linestyle='-', label='line 2')
plt.xlabel('value')
plt.ylabel('range')
plt.title('Simple Plot',fontsize=23, fontweight='bold')
plt.legend(loc='upper right', fontsize=10)
plt.show()

# %%
a=np.arange(30)
b=np.random.randint(0,30,30)
plt.scatter(a,b,c=['green'])
plt.show()

# %%
a=np.random.randint(0,50,30)
b=np.random.randint(0,30,30)
plt.scatter(a,b,c='blue',s=5)
plt.show()

# %%
category=['account a', 'account b', 'account 3']
revenue=np.array([2000,4000,1000])
plt.figure(figsize=(6,8))
plt.bar(range(0,3), revenue)
plt.xlabel(category)
plt.ylabel(revenue)

plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\matplotlib\text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
import pandas as pd

# %%
xyz_web={'day':[1,2,3,4,5,6],'visitors':[100,300,200,500,400,600],'bounce_rate':[20,30,10,12,13,32]}

# %%
df=pd.DataFrame(xyz_web)

# %%
df
# Out:
#    day  visitors  bounce_rate
# 0    1       100           20
# 1    2       300           30
# 2    3       200           10
# 3    4       500           12
# 4    5       400           13
# 5    6       600           32

# %%
df.head(2)
# Out:
#    day  visitors  bounce_rate
# 0    1       100           20
# 1    2       300           30

# %%
plt.plot(df['day'],df['visitors'])
plt.show()

# %%
plt.bar(df['day'],df['visitors'])
plt.show()

# %%
plt.barh(df['day'],df['visitors'])
plt.show()

# %%
plt.scatter(df['day'],df['visitors'])
plt.show()

# %%
df
# Out:
#    day  visitors  bounce_rate
# 0    1       100           20
# 1    2       300           30
# 2    3       200           10
# 3    4       500           12
# 4    5       400           13
# 5    6       600           32

# %%
plt.plot(df['day'], c='green', linewidth=5)
plt.plot(df['bounce_rate'], c='blue', linewidth=3)
plt.show()

# %%
color=['black','blue','green','grey','maroon']
plt.bar(df['day'],df['visitors'],color=color)
plt.xlabel('day', fontsize=20)
plt.ylabel('visitors', fontsize=20)
plt.title('survey', fontsize=40, fontweight='bold')
plt.legend(labels=[1,2,3,4,5,6])
plt.show()

# %%
x=['day1', 'day2', 'day3', 'day4', 'day5', 'day6']
y=[400,700,500,600,1000,600]
plt.bar(x,y, color=color)
plt.xlabel('days')
plt.ylabel('sales')
plt.title('Sales vs Day')
plt.show()

# %%
x=['day1', 'day2', 'day3', 'day4', 'day5', 'day6']
y=[400,700,500,600,1000,600]
plt.barh(x,y, color=color)
plt.xlabel('days')
plt.ylabel('sales')
plt.title('Sales vs Day')
plt.show()

# %%
x=['day1', 'day2', 'day3', 'day4', 'day5', 'day6']
y=[400,700,500,600,1000,600]
plt.barh(x,y, color=color)
plt.xlabel('days')
plt.ylabel('sales')
plt.title('Sales vs Day')
plt.show()

# %% [markdown]
# ## change figuresize figsize()

# %%
x=np.linspace(0,4*np.pi, 1000)
y=np.sin(x)

# %%
plt.plot(x,y);

# %%
plt.figure(figsize=(10,6))
plt.plot(x,y);

# %%
## using rcParms we can fix the size of the figure for all upcoming figures

# %%
plt.plot(x,y);

# %%
plt.plot(x,-y);

# %% [markdown]
# ## Saving a figure

# %%
np.random.seed(99)

X = np.random.rand(100)
Y = 2*X + 0.5*np.random.rand(100)

# %%
plt.scatter(X, Y);

# %%
plt.scatter(X, Y)
plt.savefig('random_scatter.png');

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
plt.scatter(X, Y)
plt.savefig('loction_to_save.png');

# %%
plt.scatter(X, Y)
plt.savefig('random_scatter.svg');

# %%
plt.scatter(X, Y)
plt.savefig('random_scatter_highres.png', dpi=200);

# %% [markdown]
# ## Figure Cutting Off

# %%
plt.scatter(X, Y)
plt.xlabel('Random Data', fontsize=24)
plt.savefig('random_scatter_xlabel_fixed.png', bbox_inches='tight');

# %% [markdown]
# ## adding math symbol

# %%
X = np.linspace(1, 4, 1000)
Y = X
Y2 = X**2
Y_log = np.log(X)
Y_cos = np.cos(np.pi*X)

# %%
import matplotlib

# %%
matplotlib.rcParams['font.size'] = 16

# %%
##superscript
plt.plot(X, Y2)
plt.title(r'$y=x^2$');

# %%
##subscript
plt.plot(X, Y)
plt.title(r'$y=x_i$');

# %%
plt.plot(X, Y)
plt.title(r'$y=x_{base}$');

# %%
plt.plot(X, Y_cos)
plt.text(2.3, 0.75, r'$y=\cos(\pi x)$');

# %%
plt.plot(X, Y_cos)
plt.title(r'$y=\cos(\pi x)$')
plt.text(2.3, 0.75, r'$y=\cos(\pi x)$')
plt.xlabel(r'$y=\cos(\pi x)$')
plt.ylabel(r'$y=\cos(\pi x)$')
plt.legend([r'$y=\cos(\pi x)$'], loc=4);

# %% [markdown]
# ## Adding formulae

# %%
x = np.linspace(0.5, 100, 1000)
y_frac = 2 + 1/(x**2);

# %%
plt.plot(x, y_frac)
plt.ylim(0, None)
plt.title(r'$y = 2 + \frac{1}{x^2}$', fontsize=20);

# %% [markdown]
# ## legend

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 1, 4, 6, 4])

# %%
plt.plot(x, y)
plt.plot(x, y+2, color='orange')
plt.legend(['blue', 'orange']);

# %%
plt.plot(x, y, label='blue')
plt.plot(x, y+2, color='orange', label='orange')
plt.legend();

# %%
line_1, = plt.plot(x, y, label='blue')
line_2, = plt.plot(x, y+2, color='orange', label='orange')
plt.legend(handles=[line_2, line_1]);

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x='petal_width',  y='petal_length', 
                data=df,
                hue='species'
               );

# %%
plt.plot(x, y, label='blue')
plt.plot(x, y+2, color='orange', label='orange')
plt.legend(loc='lower right');

# %%
plt.plot(x, 10-y, label='blue')
plt.plot(x, y+2, color='orange', label='orange')
plt.legend(loc='best');

# %%
plt.plot(x, y, label='blue')
plt.plot(x, y+2, color='orange', label='orange')
plt.legend(bbox_to_anchor=(1, 1), loc='upper left');

# %%
plt.plot(x, y, label='blue')
plt.plot(x, y+2, color='orange', label='orange')
plt.legend(ncol=2);

# %%
plt.plot(x, y, label='blue')
plt.plot(x, y+2, color='orange', label='orange')
plt.plot(x, y+4, color='green', label='green')
plt.legend(ncol=3);

# %%
plt.plot(x, y, label='blue')
plt.plot(x, y+2, color='orange', label='orange')
plt.plot(x, y+4, color='green', label='green')
plt.legend(ncol=3, bbox_to_anchor=(0.5, -0.1), loc='upper center');

# %%
plt.plot(x, y, label='blue')
plt.plot(x, y+2, color='orange', label='orange')
plt.legend(fontsize=14);

# %%
plt.plot(x, y, label='blue')
plt.plot(x, y+2, color='orange', label='orange')
plt.legend(prop={'weight': 'bold', 'size': 14, 'family': 'serif'});

# %%
plt.plot(x, y, label='blue')
plt.plot(x, y+2, color='orange', label='orange')
plt.legend(labelcolor=['blue', 'orange']);

# %%
plt.plot(x, y, label='blue')
plt.plot(x, y+2, color='orange', label='orange')
plt.legend(frameon=False);

# %%
plt.plot(x, y, label='blue')
plt.plot(x, y+2, color='orange', label='orange')
plt.legend(title='line colors');

# %%
plt.plot(x, y, label='blue')
plt.plot(x, y+2, color='orange', label='orange')
plt.legend(facecolor='lightgray');

# %%
## adding baseline to figure

# %%
X = np.linspace(0, 10, 1000)

Y = np.sin(np.pi*X/2) + 2
Y2 = 10 - (X-5)**2

# %%
plt.plot(X, Y)
plt.axhline(2);

# %%
plt.plot(X, Y2)
plt.axvline(5, ymin=0.2, ymax=.8);

# %%
plt.plot(X, Y)
plt.axhline(2, color='orangered');

# %%
plt.plot(X, Y)
plt.axhline(2, color='orangered', lw=4);

# %%
plt.plot(X, Y)
plt.axhline(2, color='orangered', lw=4, ls='--');

# %%
plt.plot(X, Y, lw=4, zorder=2)
plt.axhline(2, color='orangered', lw=4, zorder=1);

# %%
plt.plot(X, Y, lw=4, label='sine wave')
plt.axhline(2, color='orangered', lw=4, label='baseline')
plt.legend();

# %%
students = ['A', 'B', 'C', "D", "E"]
grades = [80, 42, 68, 91, 77]

plt.bar(students, grades, edgecolor='black', color='xkcd:light gray blue')
plt.axhline(100, color='xkcd:brick red', lw=3)
plt.text(2.5, 104, 'Maximum Grade', 
         fontstyle='italic',
         color='xkcd:brick red', fontweight='bold', fontsize=14)
for i,g in enumerate(grades):
    plt.text(i-0.18, g-8, f'{g}', color='black', fontsize=16)
    
plt.xlabel('Student')
sns.despine()
plt.tight_layout()
#plt.savefig('05baseline_fig_grades.png', dpi=200);

# %%
np.random.seed(44)
x = np.random.normal(2, 1, size=30)
y = np.random.normal(4, 1, size=30)

# %%
plt.scatter(x, y, c='xkcd:bruise', edgecolor='black', s=100, zorder=10)
plt.axvline(np.mean(x), color='gray', lw=6,  zorder=1)
plt.xlim(0, 4.4)
plt.ylim(0, 6.5)
plt.yticks([0, 2, 4, 6])
plt.xticks([0, 1, 2, 3, 4])
plt.text(0.45, 1, f'mean = {np.mean(x):.2f}', 
         fontstyle='italic',
         color='gray', fontweight='bold', fontsize=16)
sns.despine()
plt.tight_layout()
##plt.savefig('05baseline_figure_vertMean.png', dpi=200);

# %%
plt.scatter(x, y, c='xkcd:bruise', edgecolor='black', s=100, zorder=10)
plt.axhline(np.mean(y), color='gray', lw=6,  zorder=1)
plt.xlim(0, 4.4)
plt.ylim(0, 6.5)
plt.yticks([0, 2, 4, 6])
plt.xticks([0, 1, 2, 3, 4])
plt.annotate(f'mean = {np.mean(y):.2f}', xy=(2.7, 4), xytext=(3, 2),
             fontstyle='italic', color='gray', fontweight='bold', fontsize=16,
            arrowprops=dict(facecolor='gray', shrink=0.03, edgecolor='gray'))
sns.despine()
plt.tight_layout()
##plt.savefig('05baseline_figure_horizMean.png', dpi=200);

# %%
## adding shapes

# %%
np.random.seed(33)
X = np.random.normal(0, 3, size=50)
Y = X + np.random.normal(0, 3, size=50)

# %%
from matplotlib.patches import Rectangle

# %%
plt.scatter(X, Y, alpha=0.7)

rect = Rectangle((0, 0), 8, 12)
plt.gca().add_patch(rect);

# %%
plt.scatter(X, Y, alpha=0.7)

rect = Rectangle((0, 0), 8, 12, fill=False) 
plt.gca().add_patch(rect);

# %%
plt.scatter(X, Y, alpha=0.7)

rect = Rectangle((0, 0), 8, 12, fill=False, angle=15) 
plt.gca().add_patch(rect);

# %%
from matplotlib.patches import Circle

# %%
plt.scatter(X, Y, alpha=0.7)
plt.xlim(-11, 11)
plt.ylim(-11, 11)

circle = Circle((0,0), 6, fill=False)
plt.gca().add_patch(circle);

# %%
line_x = np.linspace(0, 10, 1001)
line_y = 5 - 2*np.abs(line_x - 5)

# %%
plt.plot(line_x, line_y, lw=3)
plt.gca().margins(0.1)

plt.axvline(5, ymax=0.87, ls='--', color='red', alpha=0.6)
plt.axhline(5, xmax=0.46, ls='--', color='red', alpha=0.6)

cir = Circle((5, 5), 0.5, color='red', lw=3, fill=False, zorder=10)
plt.gca().add_patch(cir)

plt.tight_layout()

#plt.savefig('06shapes_abs_application.png', dpi=200)

# %%
plt.figure(figsize=(8, 5))

plt.scatter(X, Y, alpha=0.7, zorder=2)

ax = plt.gca()

rect = Rectangle((0, 0), 8, 12, fill=False, lw=3, color='red', zorder=3) 
ax.add_patch(rect)

circle = Circle((-3, -5), 4, alpha=0.3, color='green', lw=10, zorder=1)
ax.add_patch(circle)

plt.tight_layout()
#plt.savefig('06shapes_shapes_example.png', dpi=200);

# %%
plt.figure(figsize=(7, 5))

plt.scatter(X, Y, alpha=0.7, zorder=2, s=150, edgecolor='black')

ax = plt.gca()

rect = Rectangle((-7, -12), 8, 12, fill=False, lw=5, color='red', zorder=3) 
ax.add_patch(rect)

sns.despine(left=True, bottom=True)
plt.xticks([])
plt.yticks([])

plt.tight_layout()
#plt.savefig('06shapes_image_thumbnail.png', dpi=200);

# %%
from matplotlib.patches import Ellipse

# %%
plt.scatter(X, Y, alpha=0.7)
plt.xlim(-11, 11)
plt.ylim(-11, 11)

ellipse = Ellipse((0,0), 5, 20, fill=False, lw=4, color='red')
plt.gca().add_patch(ellipse);

# %%
from matplotlib.patches import RegularPolygon

# %%
plt.scatter(X, Y, alpha=0.7)
plt.xlim(-11, 11)
plt.ylim(-11, 11)

poly = RegularPolygon((-3, -4), 8, alpha=0.7, color='gray')  
plt.gca().add_patch(poly);

# %% [markdown]
# ## Adiing pattern

# %%
values = [20, 40, 60]

# %%
plt.bar(range(len(values)), values, hatch='/');

# %%
plt.bar(range(len(values)), values, hatch='x');

# %%
plt.bar(range(len(values)), values, hatch='*');

# %%
patterns = ['', '\\', '']
bars = plt.bar(range(len(values)), values)

for bar, pattern in zip(bars, patterns):
    bar.set_hatch(pattern);

# %%
plt.figure(figsize=(5, 5))
plt.xlim(0, 10)
plt.ylim(0, 10)

rect = Rectangle((5, 5), 4, 4, fill=False, color='orange', lw=4, hatch='o')

cir = Circle((3, 3), 2, fill=False, color='teal', lw=4, hatch='-')

plt.gca().add_patch(rect)
plt.gca().add_patch(cir);

# %%
wedges, labels = plt.pie(values)

wedges[0].set_hatch('|');

# %%
x = np.linspace(0, 10, 100)
y1 = 25 - (5-x)**2
y2 = -y1

# %%
plt.fill_between(x, y1, y2, hatch='.');

# %%
plt.bar(range(len(values)), values, hatch='/', 
        facecolor='lightgray',
        edgecolor='deeppink'
       );

# %%
plt.bar(range(len(values)), values, hatch='/', 
        facecolor='lightgray'
       );

# %%
plt.bar(range(len(values)), values, hatch='/', facecolor='lightgray');

# %% [markdown]
# ## Adding text

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 1, 4, 6, 4])

# %%
plt.scatter(x, y)
plt.text(4, 5.5, "Peak Point");

# %%
plt.scatter(x, y)
plt.text(4, 5.5, "Peak Point")
plt.text(2, 1.3, "Low Point");

# %%
plt.scatter(x, y)
plt.text(4, 5.5, "Peak Point", ha='center')
plt.text(2.2, 1, "Low Point", va='center');

# %%
students = ['A', 'B', 'C', "D", "E"]
grades = [80, 42, 68, 91, 77]

plt.bar(students, grades, edgecolor='black', color='xkcd:light gray blue')
plt.axhline(100, color='xkcd:brick red', lw=3)

plt.text(2.5, 104, "Maximum Grade",
         fontsize=14,
         color='xkcd:brick red',
         fontweight='bold',
         fontstyle='italic'
        )
    
plt.xlabel('Student')
sns.despine();

# %%
from matplotlib.patches import Circle

line_x = np.linspace(0, 10, 1001)
line_y = 5 - 2*np.abs(line_x - 5)

# %%
plt.figure(figsize=(6, 6))
plt.plot(line_x, line_y, lw=3)
plt.gca().margins(0.1)

plt.text(6, 5, "Critical Point",
        bbox={'facecolor': 'red', 'alpha': 0.3}
        )

cir = Circle((5, 5), 0.5, color='red', lw=3, fill=False, zorder=10)
plt.gca().add_patch(cir);

# %%
plt.figure(figsize=(7,4))

np.random.seed(41)
x_vals = np.random.normal(size=20)
y_vals = np.random.normal(size=20)

plt.scatter(x_vals, y_vals, s=200, ec='black')

plt.xticks([])
plt.yticks([])
sns.despine(left=True, bottom=True);

#plt.savefig('09text_thumb.png', dpi=200, bbox_inches='tight');

# %%
students = ['A', 'B', 'C', 'D', 'E']
grades = [80, 42, 68, 91, 77]

plt.bar(students, grades, edgecolor='black', color='xkcd:light gray blue')

for i, g in enumerate(grades):
    plt.text(i, g-8, f'{g}', ha='center', fontsize=16)
    
plt.xlabel('Student')
plt.yticks([])
sns.despine(left=True)

# %% [markdown]
# ## Adding shading

# %%
x = np.random.normal(10, 1, size=50)
y = .5*x + np.random.normal(5, 1, size=50)

# %%
plt.scatter(x, y)
plt.axvspan(10, 13);

# %%
plt.scatter(x, y)
plt.axvspan(10, 13, ymin=0.5, ymax=0.75);

# %%
plt.scatter(x, y)
plt.axhspan(11, 14);

# %%
plt.scatter(x, y)
plt.axhspan(11, 14, xmin=0.25, xmax=0.5);

# %%
import pandas as pd
from datetime import datetime

# %%
dates = [datetime(2019, 11, 15), datetime(2019, 12, 15), datetime(2020, 1, 15),
         datetime(2020, 2, 15), datetime(2020, 3, 15)]
prices = [110.40, 125.22, 78.30, 66.90, 78.05]

# %%
dates
# Out:
# [datetime.datetime(2019, 11, 15, 0, 0),
#  datetime.datetime(2019, 12, 15, 0, 0),
#  datetime.datetime(2020, 1, 15, 0, 0),
#  datetime.datetime(2020, 2, 15, 0, 0),
#  datetime.datetime(2020, 3, 15, 0, 0)]

# %%
plt.figure(figsize=(6, 4))

pd.Series(prices, index=dates).plot(marker='o', markersize=10)

plt.xticks([datetime(2019, 12, 1), datetime(2020, 1, 1), 
            datetime(2020, 2, 1),datetime(2020, 3, 1)], 
           ['Dec\n2019', 'Jan\n2020', 'Feb\n2020', 'March\n2020'], 
           rotation=0, 
           ha='center'
          ) 
plt.xlim(datetime(2019, 11, 10), datetime(2020, 3, 20))
plt.ylim(50, 150)

#add shading
plt.axvspan(datetime(2019, 11, 10), datetime(2020, 1, 1), color='lightgray', alpha=0.5)

#add text: 2019, 2020
plt.text(datetime(2019, 12, 15), 140, '2019', fontsize=16, color='gray')
plt.text(datetime(2020, 1, 5), 140, '2020', fontsize=16, color='black')

sns.despine();

# %%
plt.scatter(x, y)

x_mean = np.mean(x)

x_start, x_end = plt.xlim()

#add shading with pattern
p = plt.axvspan(x_mean, x_end, alpha=0.2)
p.set_hatch('/')

plt.xlim(None, x_end);

# %%
x_val = np.linspace(-5, 5, 1000)
y_val = 20 - x_val**2

# %%
plt.fill_between(x_val, -5, y_val);

# %%
y1 = np.sin(0.5*x_val)
y2 = -3 + np.sin(-0.5*x_val)

# %%
plt.fill_between(x_val, y1, y2);

# %%
plt.fill_between(x_val, y1, y2, alpha=0.5, hatch='|');

# %% [markdown]
# ## Changing axis limit

# %%
X = np.linspace(1, 4, 1000)
Y = 2 + X**2

# %%
plt.plot(X, Y)
plt.xlim(0, 5);

# %%
plt.plot(X, Y)
plt.xlim(0, 5)
plt.ylim(0, 20);

# %%
plt.plot(X, Y)
plt.ylim(0, None);

# %%
plt.plot(X, Y)
plt.ylim(bottom=0);

# %%
plt.plot(X, Y)

ax=plt.gca()
ax.set_xlim(0, 5)
ax.set_ylim(0, None);

# %% [markdown]
# ## subplot

# %%
plt.subplots(1, 3)

plt.subplot(1, 3, 1)
plt.plot(X, Y)

ax2 = plt.subplot(1, 3, 2)
plt.scatter(X[::100], Y[::100])

#or you could put the xlim, ylim functions 
#   here to change this subplot!

plt.subplot(1, 3, 3)
plt.plot(X, -Y)

plt.tight_layout()

plt.xlim(0, 5)
plt.ylim(-20, 0)

ax2.set_xlim(-2, 6)
ax2.set_ylim(-10, 25);

# %%
plt.plot(X, Y)
plt.xlim(4, 1);

# %%
plt.plot(X, Y)
left, right = plt.xlim()
plt.xlim(right, left);

# %% [markdown]
# ## removing box around thr plot

# %%
x = range(10)
y = [0, 3, 5, 4, 5, 7, 8, 8, 7, 9]

# %%
plt.plot(x, y)
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False);

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
ax.spines

# %%
plt.plot(x, y)
ax = plt.gca()
ax.set_frame_on(False);

# %%
plt.plot(x, y);

# %%
plt.plot(x, y)
sns.despine();

# %%
plt.plot(x, y)
sns.despine(left=True, right=False);

# %%
plt.figure(figsize=(6, 4))
plt.plot(x, y, lw=5)
plt.xticks([])
plt.yticks([])
ax = plt.gca()
ax.spines['right'].set_color('gray')
ax.spines['right'].set_linestyle((0,(10,10)))
for spine in ax.spines:
    ax.spines[spine].set_linewidth(2)
ax.spines['right'].set_linewidth(1)
#plt.savefig('11spines_thumb.png', dpi=200, bbox_inches='tight');

# %%
plt.figure(figsize=(6, 4))
plt.plot(x, y, lw=5)
plt.xticks([])
plt.yticks([])
ax = plt.gca()
ax.set_frame_on(False)
#plt.savefig('11spines_noframe.png', dpi=200, bbox_inches='tight');

# %%
spine_list = ['bottom', 'right', 'top', 'left']
for i in range(len(spine_list)):
    plt.figure(figsize=(6, 4))
    plt.plot(x, y, lw=5)
    plt.xticks([])
    plt.yticks([])
    ax = plt.gca()
    for spine in spine_list[:i]:
        ax.spines[spine].set_visible(False)
    ax.spines[spine_list[i]].set_linewidth(5)
    ax.spines[spine_list[i]].set_color('darkorange')

# %% [markdown]
# ## 3D plot

# %%
np.random.seed(31)

mu = 3
n=50

x = np.random.normal(mu, 1, size=n)
y = np.random.normal(mu, 1, size=n)
z = np.random.normal(mu, 1, size=n)

# %%
ax = plt.axes(projection='3d');

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(x, y, z);

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(x, y, z, s=100)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(x, y, z, s=100)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.view_init(45, 215);

# %%
omega = 2

z_line = np.linspace(0, 10, 100)
x_line = np.cos(omega*z_line)
y_line = np.sin(omega*z_line)

# %%
ax = plt.axes(projection='3d')
ax.plot3D(x_line, y_line, z_line, lw=4);

# %%
# %matplotlib notebook

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(x, y, z, s=100, edgecolor='black')
plt.yticks([]);
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2924/1766863260.py in <module>
#       1 fig = plt.figure()
#       2 ax = plt.axes(projection='3d')
# ----> 3 ax.scatter3D(x, y, z, s=100, edgecolor='black')
#       4 plt.yticks([]);
#
# ~\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2404         zs_orig = zs
#    2405
# -> 2406         xs, ys, zs = np.broadcast_arrays(
#    2407             *[np.ravel(np.ma.filled(t, np.nan)) for t in [xs, ys, zs]])
#    2408         s = np.ma.ravel(s)  # This doesn't have to match x, y in size.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(subok, *args)
#     536     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     537
# --> 538     shape = _broadcast_shape(*args)
#     539
#     540     if all(array.shape == shape for array in args):
#
# ~\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     418     # use the old-iterator because np.nditer does not handle size 0 arrays
#     419     # consistently
# --> 420     b = np.broadcast(*args[:32])
#     421     # unfortunately, it cannot handle 32 or more arguments directly
#     422     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(x, y, z);
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2924/2907730441.py in <module>
#       1 fig = plt.figure()
#       2 ax = plt.axes(projection='3d')
# ----> 3 ax.scatter3D(x, y, z);
#
# ~\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2404         zs_orig = zs
#    2405
# -> 2406         xs, ys, zs = np.broadcast_arrays(
#    2407             *[np.ravel(np.ma.filled(t, np.nan)) for t in [xs, ys, zs]])
#    2408         s = np.ma.ravel(s)  # This doesn't have to match x, y in size.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(subok, *args)
#     536     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     537
# --> 538     shape = _broadcast_shape(*args)
#     539
#     540     if all(array.shape == shape for array in args):
#
# ~\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     418     # use the old-iterator because np.nditer does not handle size 0 arrays
#     419     # consistently
# --> 420     b = np.broadcast(*args[:32])
#     421     # unfortunately, it cannot handle 32 or more arguments directly
#     422     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %% [markdown]
# ## adding secondary y axis

# %%
x = np.linspace(0, 100, 1000)

x_sqrt = np.sqrt(x)
x_squared = x**2

# %%
plt.plot(x, x)
plt.plot(x, x_sqrt);

# %%
fig, ax1 = plt.subplots()
ax1.plot(x, x)
ax1.set_ylabel('Linear')

ax2 = ax1.twinx()

ax2.plot(x, x_sqrt, color='orange')
ax2.set_ylabel('Square Root');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax1 = plt.subplots()

color1 = 'blue'
ax1.plot(x, x, color=color1)
ax1.set_ylabel('Linear', color=color1)
ax1.tick_params(axis='y', labelcolor=color1)

ax2 = ax1.twinx()

color2 = 'crimson'
ax2.plot(x, x_sqrt, color=color2)
ax2.set_ylabel('Square Root', color=color2)
ax2.tick_params(axis='y', labelcolor=color2)

ax2.spines['left'].set_color(color1)
ax2.spines['right'].set_color(color2);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax1 = plt.subplots()
ax1.plot(x, x, label='Linear')
ax1.set_ylabel('Linear')
ax1.legend()

ax2 = ax1.twinx()

line2 = ax2.plot(x, x_sqrt, color='orange', label="Sqrt")  
ax2.set_ylabel('Square Root')
ax2.legend(loc=1);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax1 = plt.subplots()
line1 = ax1.plot(x, x, label='Linear')
ax1.set_ylabel('Linear')


ax2 = ax1.twinx()
line2 = ax2.plot(x, x_sqrt, color='orange', label='Sqrt')  
ax2.set_ylabel('Square Root')

lines = line1 + line2
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax1 = plt.subplots()
ax1.plot(x, x)
ax1.set_ylabel('Linear')

ax2 = ax1.twinx()
ax2.plot(x_sqrt, x_sqrt, color='orange')  #Note: x-axis is now x_sqrt
ax2.set_ylabel('Square Root');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(x, x)
plt.plot(x_sqrt, x_sqrt);

# %%
sns.set_style('darkgrid')

ax1 = sns.lineplot(x=x, y=x, ci=None)

ax2 = ax1.twinx()

sns.lineplot(x=x, y=x_sqrt, color='orange', ci=None, ax=ax2)
ax2.grid(False);

# %% [markdown]
# # Pieplot

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6,6))
student_name=['suraj', 'aman', 'sita', 'rina']
marks=[87,57,87,90]
plt.pie(marks, labels=student_name, startangle=90, explode=[0.1,0,0,0],
       shadow=True, autopct='%2.1f%%' )
plt.legend(title='student_name');
